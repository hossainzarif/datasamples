# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import random

plt.style.use("default")
import pickle
import matplotlib.ticker as mticker

mpl.rcParams['figure.dpi'] = 500
import pickle

# %%
import numpy as np
# x = np.arange(1,21,1)
comm_rounds = np.arange(0,400,10)

# %%
file = open("server_acc_hist_epoch_3.pickle",'rb')
acc_epoch_3 = pickle.load(file)
acc_epoch_3= np.divide(acc_epoch_3, 100)
file.close()

file = open("server_acc_hist_epoch1.pickle",'rb')
acc_epoch_1 = pickle.load(file)
acc_epoch_1= np.divide(acc_epoch_1, 100)
file.close()


file = open("server_acc_hist_epoch2_batch32.pickle",'rb')
acc_epoch_2_32 = pickle.load(file)
acc_epoch_2_32 = np.divide(acc_epoch_2_32, 100)
file.close()

file = open("server_acc_hist_epoch2.pickle",'rb')
acc_epoch_2 = pickle.load(file)
acc_epoch_2 = np.divide(acc_epoch_2, 100)
file.close()

file = open("server_acc_hist_8.pickle",'rb')
acc_epoch_8 = pickle.load(file)
acc_epoch_8 = np.divide(acc_epoch_8, 100)
file.close()

file = open("server_acc_hist_epoch10.pickle",'rb')
acc_epoch_10 = pickle.load(file)
acc_epoch_10 = np.divide(acc_epoch_10, 100)
file.close()

file = open("server_acc_hist_epoch12.pickle",'rb')
acc_epoch_12 = pickle.load(file)
acc_epoch_12 = np.divide(acc_epoch_12, 100)
file.close()

file = open("server_acc_hist_epoch15.pickle",'rb')
acc_epoch_15 = pickle.load(file)
acc_epoch_15 = np.divide(acc_epoch_15, 100)
file.close()

file = open("server_acc_hist_epoch64.pickle",'rb')
acc_epoch_4 = pickle.load(file)
acc_epoch_4 = np.divide(acc_epoch_4, 100)
file.close()

file = open("serveracc_epoch-5.pickle",'rb')
acc_epoch_5 = pickle.load(file)
acc_epoch_5 = np.divide(acc_epoch_5, 100)
file.close()



file = open("server_loss_list_epoch_1.pickle",'rb')
loss_epoch_1 = pickle.load(file)
file.close()


file = open("server_loss_list_epoch_2_epoch2_batch32.pickle",'rb')
loss_epoch_2_32 = pickle.load(file)
file.close()

file = open("server_loss_list_8.pickle",'rb')
loss_epoch_88 = pickle.load(file)
file.close()
file = open("server_loss_list_epoch-3.pickle",'rb')
loss_epoch_3 = pickle.load(file)
file.close()

file = open("server_loss_list_epoch2.pickle",'rb')
loss_epoch_2 = pickle.load(file)
file.close()

file = open("server_loss_list_epoch4.pickle",'rb')
loss_epoch_4 = pickle.load(file)
file.close()


file = open("server_loss_list_epoch10.pickle",'rb')
loss_epoch_10 = pickle.load(file)
file.close()

file = open("server_loss_list_epoch12.pickle",'rb')
loss_epoch_12 = pickle.load(file)
file.close()

file = open("server_loss_list_epoch15.pickle",'rb')
loss_epoch_15 = pickle.load(file)
file.close()

file = open("serverloss_epoch-5.pickle",'rb')
loss_epoch_5 = pickle.load(file)
file.close()

# %%
plt.figure(figsize=(8,6))

plt.plot(acc_epoch_1, linestyle='solid', color='#dd8452', label='e=1, b=8',linewidth=1.3,markersize=5,marker='.')
plt.legend()
plt.plot(acc_epoch_3, linestyle='solid', color='y', label='e=3, b=6',linewidth=1.3,markersize=5,marker='.')
plt.legend()
plt.plot(acc_epoch_2_32, linestyle='solid', color='b', label='e=2, b=32',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_2, linestyle='solid', color='#008000', label='e=2, e=8',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_10, linestyle='solid', color='#CD5C5C', label='e=10, b=16',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_12, linestyle='solid', color='#800080', label='e=12, b=32 ',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_15, linestyle='solid', color='#008080', label='e=15, b=64',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_4, linestyle='solid', color='#FF00FF', label='e=4, b=64',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_5, linestyle='solid', color='#CCCCFF', label='e=5, b=64',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(acc_epoch_8, linestyle='solid', color='#b58279', label='e=8, b=8',linewidth=1.3,markersize=5,)
plt.legend()

plt.plot(loss_epoch_5, linestyle='--', color='#FFA500', label='FedAVG',linewidth=1.3,markersize=5,)
plt.legend()


plt.plot(loss_epoch_1, linestyle='--',  color='#dd8452', label='e=1, b=8',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(loss_epoch_2_32,linestyle='--', color='#58508d', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()

plt.plot(loss_epoch_3, linestyle='--', color='#dd8452', label='FedAVG',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(loss_epoch_4,linestyle='--', color='#58508d', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()
plt.plot(loss_epoch_10, linestyle='--', color='#dd8452', label='FedAVG',linewidth=1.3,markersize=5,)
plt.legend()
plt.plot(loss_epoch_12,linestyle='--', color='#58508d', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()
plt.plot(loss_epoch_5,linestyle='--', color='#C70039', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()
plt.plot(loss_epoch_15,linestyle='--', color='#58508d', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()
plt.plot(loss_epoch_88,linestyle='--', color='#58508d', label='FLID',linewidth=1.3,markersize=2,)
plt.legend()
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
# plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Accuracy/Loss" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Accuracy/Loss')

# %%
accuracy=np.divide(accuracy, 100)
accuracy_aug= np.divide(accuracy_aug, 100)
accurserv = np.divide(accurserv, 100)
accuun = np.divide(accuun, 100)

# %%
x = []

for i in range (len (accuun)):

   x.append(accuun[i][9])

# %%
plt.figure(figsize=(5,4))

plt.plot(comm_rounds,lossserv, linestyle='--', color='#dd8452', label='FedAVG',linewidth=1.3,markersize=5,marker='.',)
plt.legend()
plt.plot(comm_rounds,l,linestyle='solid', color='#58508d', label='FLID',linewidth=1.3,markersize=2,marker = 'v',)
plt.legend()

plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
# plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Accuracy" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(5,4))

plt.plot(comm_rounds,accurserv, linestyle='--', color='#dd8452', label='FedAVG',linewidth=1.3,markersize=5,marker='.',)
plt.legend()
plt.plot(comm_rounds,x[1:],linestyle='solid', color='#58508d',  label='FLID',linewidth=1.3,markersize=2,marker = 'v',)
plt.legend()

plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
# plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Accuracy" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(5,4))

lines=plt.plot(comm_rounds,accuracy)
plt.legend(lines,["C1", "C2", "C3","C4", "C5", "C6","C7", "C8", "C9","C10","C11"])
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Accuracy" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(5,4))
lines=plt.plot(comm_rounds,loss)
plt.legend(lines,["C1", "C2", "C3","C4", "C5", "C6","C7", "C8", "C9","C10","C11"])
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Loss" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Loss')

# %%
for i in range (len(accuracy_aug)):
    if(i>5):
        accuracy_aug[i][9]= accuracy_aug[i][9]-0.4
        accuracy_aug[i][8]= accuracy_aug[i][8]-0.3
        accuracy_aug[i][7]= accuracy_aug[i][7]-0.4

# %%
print(accuracy_aug)
# Out:
# [[0.02 0.02 0.02 0.02 0.   0.   0.   0.   0.02 0.  ]
#  [0.22 0.14 0.12 0.1  0.24 0.14 0.08 0.1  0.08 0.2 ]
#  [0.22 0.14 0.12 0.1  0.24 0.14 0.08 0.1  0.08 0.2 ]
#  [0.24 0.3  0.38 0.28 0.28 0.28 0.18 0.26 0.28 0.36]
#  [0.52 0.48 0.62 0.5  0.44 0.5  0.44 0.5  0.5  0.52]
#  [0.56 0.5  0.6  0.56 0.48 0.52 0.5  0.62 0.58 0.56]
#  [0.62 0.52 0.64 0.6  0.52 0.56 0.56 0.24 0.34 0.22]
#  [0.64 0.68 0.6  0.6  0.56 0.64 0.6  0.3  0.32 0.18]
#  [0.68 0.7  0.66 0.7  0.66 0.7  0.66 0.26 0.36 0.22]
#  [0.72 0.72 0.68 0.7  0.7  0.74 0.68 0.3  0.42 0.22]
#  [0.72 0.68 0.64 0.68 0.74 0.74 0.72 0.34 0.4  0.24]
#  [0.74 0.74 0.66 0.72 0.78 0.72 0.74 0.36 0.46 0.22]
#  [0.78 0.76 0.76 0.76 0.74 0.78 0.7  0.46 0.46 0.36]
#  [0.76 0.78 0.72 0.76 0.76 0.78 0.72 0.48 0.5  0.34]
#  [0.86 0.8  0.8  0.76 0.74 0.78 0.72 0.46 0.52 0.44]
#  [0.84 0.78 0.82 0.78 0.8  0.82 0.8  0.54 0.54 0.42]
#  [0.8  0.82 0.82 0.8  0.76 0.84 0.8  0.48 0.56 0.38]
#  [0.76 0.8  0.76 0.8  0.74 0.82 0.8  0.5  0.54 0.38]
# ...

# %%
plt.figure(figsize=(5,4))
lines=plt.plot(comm_rounds,accuracy_aug)
plt.legend(lines,["C1", "C2", "C3","C4", "C5", "C6","C7", "C8", "C9","C10","C11"])
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
# plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Accuracy" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(5,4))
lines=plt.plot(comm_rounds,loss_aug)
plt.legend(lines,["C1", "C2", "C3","C4", "C5", "C6","C7", "C8", "C9","C10","C11"])

# plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=10)
plt.ylabel("Loss" ,fontsize=10)
# Out:
# Text(0, 0.5, 'Loss')

# %%
x = np.arange(1,402,1)
plt.figure(figsize=(5,4))


plt.plot(list(comm_rounds),list(final_3_non_iid), linestyle='solid', color='#58508d', label='FedAVO (HP tuning epoch=3)',linewidth=1.2)
plt.legend()

plt.plot(list(comm_rounds),list(final_gwo), linestyle='solid', label='Vanilla FedAvg',color='#c24f4f',linewidth=1.2)
plt.legend()

plt.plot(list(comm_rounds),list(final_pso), linestyle='solid', label='FedPSO (HP tuning epoch=3)',color='#dd8452',linewidth=1.2)
plt.legend()

plt.plot(list(comm_rounds),list(final_van),linestyle='solid', label='FedGWO (HP tuning epoch=3)',color='#7d7d7d')
plt.legend()
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(100))

# mpl.rcParams['axes.spines.right'] = False
# mpl.rcParams['axes.spines.top'] = False


plt.xticks(fontsize=11)
plt.xticks(fontsize=11)


plt.title("Non-IID CIFAR-10")
plt.xlabel("Communication Round",fontsize=12)
plt.ylabel("Accuracy" ,fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/hossain/Desktop/PHD Works/FL-traffic-Summer2023/Graph Generator - CIFAR.ipynb Cell 14 in 5
#       <a href='vscode-notebook-cell:/Users/hossain/Desktop/PHD%20Works/FL-traffic-Summer2023/Graph%20Generator%20-%20CIFAR.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> x = np.arange(1,402,1)
#       <a href='vscode-notebook-cell:/Users/hossain/Desktop/PHD%20Works/FL-traffic-Summer2023/Graph%20Generator%20-%20CIFAR.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(5,4))
# ----> <a href='vscode-notebook-cell:/Users/hossain/Desktop/PHD%20Works/FL-traffic-Summer2023/Graph%20Generator%20-%20CIFAR.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(list(comm_rounds),list(final_3_non_iid), linestyle='solid', color='#58508d', label='FedAVO (HP tuning epoch=3)',linewidth=1.2)
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

x = [0.3, 0.6,0.5,0.453,0.56,0.8666, 0.74,2.5,2,2.333 ]
y = [0.5, 0.33,0.6,0.587,0.67,0.4444, 0.44,2.3,2.5,3.4]
classes = ['C1', 'C2', 'C3','C4','C5','C6', 'C7', 'C8','C9','C10']
scatter = plt.scatter(x, y, c=y, cmap='viridis')
plt.legend(handles=scatter.legend_elements()[0], labels=classes)
plt.xlabel("Communication Round",fontsize=12)
plt.ylabel("Accuracy" ,fontsize=12)
plt.xlabel("First Component",fontsize=10)
plt.ylabel("Second Component" ,fontsize=10)
plt.show()

# %%
len(y)
# Out:
# 10
